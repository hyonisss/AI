# %% [markdown]
# # Multi Layer Perceptron (MLP)

# %% [markdown]
# >### [예제 5] Digit Sign Classification : SLP/MLP Using tf.keras(Adam Optimizer)

# %% [markdown]
# >### Load modules

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import cv2
from sklearn.model_selection import train_test_split

print("NumPy Version :{}".format(np.__version__))
print("TensorFlow Version :{}".format(tf.__version__))
print("Matplotlib Version :{}".format(plt.matplotlib.__version__))
# Out:
# NumPy Version :1.18.5
# TensorFlow Version :2.3.0
# Matplotlib Version :3.2.2

# %% [markdown]
# > ### Load Digit Sign Image

# %%
colab=True
try:
  from google.colab import drive
except:
  colab =False
if colab : 
    drive.mount('/content/drive')
    print('g-drive mounted.')
else : print('local drive.')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# g-drive mounted.

# %%
# file path: 다른 경로에 실습파일을 복사했다면, 아래 경로를 수정하세요

if colab : 
  # !unzip -q -o /content/drive/My\ Drive/files/Sign-Language-Digits-Dataset-master.zip
  files_path = '/content/Sign-Language-Digits-Dataset-master/Dataset/'
else : 
  files_path = 'c:/files/Sign-Language-Digits-Dataset-master/datasets/'

# %%
# %%time
IMG_SIZE = 64
first = True
for ind in range(0, 10, 1) :
  path = files_path + str(ind) + '/*.*'
  print(path)
  files = glob.glob(path)
  tmpx = np.array([(cv2.resize(cv2.cvtColor(cv2.imread(x, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB), (IMG_SIZE,IMG_SIZE))) for x in files])
  tmpy = np.array([ind] * len(files))
  xtrain, xtest, ytrain, ytest = train_test_split(tmpx, tmpy, test_size=0.2, random_state=123)
  if first == True:
    train_data = xtrain.copy()
    train_labels = ytrain.copy()
    test_data = xtest.copy()
    test_labels = ytest.copy()
    first = False
  else :
    train_data = np.concatenate((train_data, xtrain))
    train_labels = np.concatenate((train_labels, ytrain))
    test_data = np.concatenate((test_data, xtest))
    test_labels = np.concatenate((test_labels, ytest))
# Out:
# /content/Sign-Language-Digits-Dataset-master/Dataset/0/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/1/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/2/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/3/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/4/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/5/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/6/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/7/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/8/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/9/*.*
# CPU times: user 1.1 s, sys: 103 ms, total: 1.2 s
# Wall time: 1.19 s

# %%
train_data = train_data / 255.0
test_data = test_data / 255.0

print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (1645, 64, 64, 3)
# (1645,)
# (417, 64, 64, 3)
# (417,)

# %% [markdown]
# >### Create Model

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(IMG_SIZE, IMG_SIZE,3)),
  # tf.keras.layers.Dense(256, activation='sigmoid'),
  # tf.keras.layers.Dense(256, activation='sigmoid'),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 12288)             0
# _________________________________________________________________
# dense (Dense)                (None, 10)                122890
# =================================================================
# Total params: 122,890
# Trainable params: 122,890
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ### 학습 전 상황

# %%
def Make_Result_Plot(suptitle:str, data:np.ndarray, label:np.ndarray, y_max:np.ndarray):
    fig_result, ax_result = plt.subplots(2,5,figsize=(18, 7))
    fig_result.suptitle(suptitle)
    for idx in range(10):
        ax_result[idx//5][idx%5].imshow(data[idx*40+40].reshape((IMG_SIZE,IMG_SIZE, 3)),cmap="binary")
        ax_result[idx//5][idx%5].set_title("test_data[{}] (label : {} / y : {})".format(idx*40+40, label[idx*40+40], y_max[idx*40+40]))

# %%
y_out = model.predict(test_data)
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))
Make_Result_Plot("Before Training", test_data, test_labels, y_max)

# %% [markdown]
# > ### 학습 (Training)

# %%
# %%time
history = model.fit(train_data, train_labels, shuffle=True,
                 batch_size=100, epochs=100,
                 validation_data=(test_data, test_labels)
                 )
# Out:
# Epoch 1/100
# 17/17 [==============================] - 0s 16ms/step - loss: 7.4600 - accuracy: 0.1070 - val_loss: 4.0356 - val_accuracy: 0.1007
# Epoch 2/100
# 17/17 [==============================] - 0s 5ms/step - loss: 3.9896 - accuracy: 0.1793 - val_loss: 2.2463 - val_accuracy: 0.2686
# Epoch 3/100
# 17/17 [==============================] - 0s 6ms/step - loss: 2.2881 - accuracy: 0.2553 - val_loss: 2.1239 - val_accuracy: 0.3429
# Epoch 4/100
# 17/17 [==============================] - 0s 6ms/step - loss: 1.8502 - accuracy: 0.3787 - val_loss: 1.7913 - val_accuracy: 0.3789
# Epoch 5/100
# 17/17 [==============================] - 0s 6ms/step - loss: 1.6175 - accuracy: 0.4809 - val_loss: 1.7875 - val_accuracy: 0.4005
# Epoch 6/100
# 17/17 [==============================] - 0s 5ms/step - loss: 1.5058 - accuracy: 0.5331 - val_loss: 1.4895 - val_accuracy: 0.5731
# Epoch 7/100
# 17/17 [==============================] - 0s 5ms/step - loss: 1.3607 - accuracy: 0.5964 - val_loss: 1.3948 - val_accuracy: 0.5612
# Epoch 8/100
# 17/17 [==============================] - 0s 6ms/step - loss: 1.2782 - accuracy: 0.6304 - val_loss: 1.4649 - val_accuracy: 0.5228
# Epoch 9/100
# 17/17 [==============================] - 0s 5ms/step - loss: 1.2748 - accuracy: 0.5793 - val_loss: 1.4307 - val_accuracy: 0.5252
# Epoch 10/100
# 17/17 [==============================] - 0s 6ms/step - loss: 1.2070 - accuracy: 0.6316 - val_loss: 1.2785 - val_accuracy: 0.5851
# Epoch 11/100
# 17/17 [==============================] - 0s 6ms/step - loss: 1.1351 - accuracy: 0.6310 - val_loss: 1.2584 - val_accuracy: 0.6067
# Epoch 12/100
# 17/17 [==============================] - 0s 6ms/step - loss: 1.0843 - accuracy: 0.6535 - val_loss: 1.2248 - val_accuracy: 0.5995
# Epoch 13/100
# 17/17 [==============================] - 0s 5ms/step - loss: 1.0182 - accuracy: 0.6900 - val_loss: 1.2036 - val_accuracy: 0.6235
# Epoch 14/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.9703 - accuracy: 0.7167 - val_loss: 1.1029 - val_accuracy: 0.6619
# Epoch 15/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9757 - accuracy: 0.7058 - val_loss: 1.0988 - val_accuracy: 0.6331
# Epoch 16/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.9430 - accuracy: 0.7027 - val_loss: 1.1815 - val_accuracy: 0.6139
# Epoch 17/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.9084 - accuracy: 0.7246 - val_loss: 1.0523 - val_accuracy: 0.6787
# Epoch 18/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.8831 - accuracy: 0.7289 - val_loss: 1.0660 - val_accuracy: 0.6523
# Epoch 19/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8513 - accuracy: 0.7532 - val_loss: 1.1413 - val_accuracy: 0.6667
# Epoch 20/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8238 - accuracy: 0.7593 - val_loss: 1.2258 - val_accuracy: 0.5659
# Epoch 21/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8420 - accuracy: 0.7441 - val_loss: 0.9972 - val_accuracy: 0.6835
# Epoch 22/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.8125 - accuracy: 0.7532 - val_loss: 1.0129 - val_accuracy: 0.6667
# Epoch 23/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.8242 - accuracy: 0.7289 - val_loss: 1.0593 - val_accuracy: 0.6427
# Epoch 24/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7342 - accuracy: 0.7775 - val_loss: 0.9895 - val_accuracy: 0.6859
# Epoch 25/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.7511 - accuracy: 0.7660 - val_loss: 1.0826 - val_accuracy: 0.6403
# Epoch 26/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.8077 - accuracy: 0.7380 - val_loss: 1.0574 - val_accuracy: 0.6811
# Epoch 27/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7375 - accuracy: 0.7690 - val_loss: 1.1151 - val_accuracy: 0.6475
# Epoch 28/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7288 - accuracy: 0.7799 - val_loss: 1.0197 - val_accuracy: 0.6643
# Epoch 29/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.7605 - accuracy: 0.7556 - val_loss: 1.0859 - val_accuracy: 0.6379
# Epoch 30/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7015 - accuracy: 0.7781 - val_loss: 0.9728 - val_accuracy: 0.6882
# Epoch 31/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6555 - accuracy: 0.7988 - val_loss: 0.9882 - val_accuracy: 0.6787
# Epoch 32/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6202 - accuracy: 0.8195 - val_loss: 0.9371 - val_accuracy: 0.7194
# Epoch 33/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6613 - accuracy: 0.8030 - val_loss: 1.0391 - val_accuracy: 0.6499
# Epoch 34/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7060 - accuracy: 0.7781 - val_loss: 0.9611 - val_accuracy: 0.6835
# Epoch 35/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6147 - accuracy: 0.8176 - val_loss: 0.9137 - val_accuracy: 0.7098
# Epoch 36/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6204 - accuracy: 0.8103 - val_loss: 0.9614 - val_accuracy: 0.6859
# Epoch 37/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5881 - accuracy: 0.8280 - val_loss: 0.9650 - val_accuracy: 0.6787
# Epoch 38/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6111 - accuracy: 0.8116 - val_loss: 1.0682 - val_accuracy: 0.6211
# Epoch 39/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6852 - accuracy: 0.7818 - val_loss: 0.9379 - val_accuracy: 0.6763
# Epoch 40/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5710 - accuracy: 0.8292 - val_loss: 0.8868 - val_accuracy: 0.7146
# Epoch 41/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5505 - accuracy: 0.8310 - val_loss: 1.1277 - val_accuracy: 0.6163
# Epoch 42/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6160 - accuracy: 0.8097 - val_loss: 0.9473 - val_accuracy: 0.6882
# Epoch 43/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5632 - accuracy: 0.8322 - val_loss: 0.8723 - val_accuracy: 0.7266
# Epoch 44/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5806 - accuracy: 0.8158 - val_loss: 0.9114 - val_accuracy: 0.7170
# Epoch 45/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5795 - accuracy: 0.8219 - val_loss: 0.9489 - val_accuracy: 0.7026
# Epoch 46/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5404 - accuracy: 0.8505 - val_loss: 0.9548 - val_accuracy: 0.6739
# Epoch 47/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5419 - accuracy: 0.8401 - val_loss: 0.9414 - val_accuracy: 0.6571
# Epoch 48/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5427 - accuracy: 0.8340 - val_loss: 1.0634 - val_accuracy: 0.6595
# Epoch 49/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5825 - accuracy: 0.8085 - val_loss: 1.2040 - val_accuracy: 0.6211
# Epoch 50/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5874 - accuracy: 0.8188 - val_loss: 0.9025 - val_accuracy: 0.7218
# Epoch 51/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5204 - accuracy: 0.8438 - val_loss: 0.9078 - val_accuracy: 0.7266
# Epoch 52/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4749 - accuracy: 0.8650 - val_loss: 1.1018 - val_accuracy: 0.6523
# Epoch 53/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4970 - accuracy: 0.8517 - val_loss: 0.8977 - val_accuracy: 0.7002
# Epoch 54/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4955 - accuracy: 0.8578 - val_loss: 0.9137 - val_accuracy: 0.6906
# Epoch 55/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4538 - accuracy: 0.8772 - val_loss: 0.9094 - val_accuracy: 0.6763
# Epoch 56/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5125 - accuracy: 0.8444 - val_loss: 1.0059 - val_accuracy: 0.6906
# Epoch 57/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5117 - accuracy: 0.8377 - val_loss: 1.0365 - val_accuracy: 0.6763
# Epoch 58/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5920 - accuracy: 0.8055 - val_loss: 0.9203 - val_accuracy: 0.7002
# Epoch 59/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.8298 - val_loss: 1.0484 - val_accuracy: 0.6787
# Epoch 60/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4915 - accuracy: 0.8438 - val_loss: 0.9839 - val_accuracy: 0.6667
# Epoch 61/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4714 - accuracy: 0.8608 - val_loss: 1.1941 - val_accuracy: 0.6259
# Epoch 62/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5710 - accuracy: 0.8055 - val_loss: 0.9365 - val_accuracy: 0.7026
# Epoch 63/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4769 - accuracy: 0.8541 - val_loss: 0.9370 - val_accuracy: 0.6930
# Epoch 64/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4644 - accuracy: 0.8547 - val_loss: 0.9359 - val_accuracy: 0.6882
# Epoch 65/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4620 - accuracy: 0.8547 - val_loss: 0.9528 - val_accuracy: 0.7170
# Epoch 66/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4164 - accuracy: 0.8802 - val_loss: 1.0800 - val_accuracy: 0.6547
# Epoch 67/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4649 - accuracy: 0.8608 - val_loss: 0.9098 - val_accuracy: 0.6954
# Epoch 68/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4370 - accuracy: 0.8784 - val_loss: 0.9602 - val_accuracy: 0.6859
# Epoch 69/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4279 - accuracy: 0.8736 - val_loss: 0.9417 - val_accuracy: 0.7074
# Epoch 70/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4555 - accuracy: 0.8571 - val_loss: 0.8761 - val_accuracy: 0.7362
# Epoch 71/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4060 - accuracy: 0.8888 - val_loss: 1.0056 - val_accuracy: 0.6763
# Epoch 72/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3811 - accuracy: 0.8930 - val_loss: 0.8588 - val_accuracy: 0.7218
# Epoch 73/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3879 - accuracy: 0.8936 - val_loss: 0.9097 - val_accuracy: 0.7194
# Epoch 74/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3811 - accuracy: 0.8912 - val_loss: 0.8365 - val_accuracy: 0.7314
# Epoch 75/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3707 - accuracy: 0.8997 - val_loss: 0.9772 - val_accuracy: 0.6906
# Epoch 76/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4009 - accuracy: 0.8851 - val_loss: 0.9697 - val_accuracy: 0.6882
# Epoch 77/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3869 - accuracy: 0.8912 - val_loss: 0.8774 - val_accuracy: 0.7410
# Epoch 78/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3969 - accuracy: 0.8912 - val_loss: 1.0386 - val_accuracy: 0.6906
# Epoch 79/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4433 - accuracy: 0.8626 - val_loss: 0.9132 - val_accuracy: 0.7194
# Epoch 80/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3817 - accuracy: 0.8912 - val_loss: 0.8689 - val_accuracy: 0.7338
# Epoch 81/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3814 - accuracy: 0.8912 - val_loss: 0.9260 - val_accuracy: 0.6978
# Epoch 82/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3727 - accuracy: 0.9003 - val_loss: 1.0935 - val_accuracy: 0.6523
# Epoch 83/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3860 - accuracy: 0.8821 - val_loss: 1.0736 - val_accuracy: 0.6643
# Epoch 84/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3712 - accuracy: 0.8942 - val_loss: 0.9608 - val_accuracy: 0.7074
# Epoch 85/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.3393 - accuracy: 0.9058 - val_loss: 0.9290 - val_accuracy: 0.6906
# Epoch 86/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3454 - accuracy: 0.9064 - val_loss: 0.9434 - val_accuracy: 0.6930
# Epoch 87/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3274 - accuracy: 0.9100 - val_loss: 0.9112 - val_accuracy: 0.7242
# Epoch 88/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3368 - accuracy: 0.9070 - val_loss: 0.9136 - val_accuracy: 0.7074
# Epoch 89/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3016 - accuracy: 0.9295 - val_loss: 0.9002 - val_accuracy: 0.7218
# Epoch 90/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3050 - accuracy: 0.9204 - val_loss: 0.8837 - val_accuracy: 0.7194
# Epoch 91/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3385 - accuracy: 0.9003 - val_loss: 0.9896 - val_accuracy: 0.6930
# Epoch 92/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3263 - accuracy: 0.9070 - val_loss: 0.9591 - val_accuracy: 0.6811
# Epoch 93/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3061 - accuracy: 0.9271 - val_loss: 0.9099 - val_accuracy: 0.7122
# Epoch 94/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3250 - accuracy: 0.9143 - val_loss: 0.9814 - val_accuracy: 0.6859
# Epoch 95/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3112 - accuracy: 0.9161 - val_loss: 0.8369 - val_accuracy: 0.7290
# Epoch 96/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3351 - accuracy: 0.9082 - val_loss: 1.0266 - val_accuracy: 0.6715
# Epoch 97/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3770 - accuracy: 0.8839 - val_loss: 0.9525 - val_accuracy: 0.6835
# Epoch 98/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3201 - accuracy: 0.9149 - val_loss: 1.0799 - val_accuracy: 0.6691
# Epoch 99/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3350 - accuracy: 0.9009 - val_loss: 0.9632 - val_accuracy: 0.6954
# Epoch 100/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3233 - accuracy: 0.9064 - val_loss: 0.9327 - val_accuracy: 0.6906
# CPU times: user 12.8 s, sys: 1.14 s, total: 13.9 s
# Wall time: 11.1 s

# %% [markdown]
# > ### Ploting : Cost/Training Count

# %%
loss = history.history['loss']
epochs = range(1, len(loss)+1)

plt.figure(figsize=(6, 10))
plt.subplot(2, 1, 1)
plt.title('Accuray')
plt.plot(epochs, history.history['accuracy'], 'b', label='train_accuracy')
plt.plot(epochs, history.history['val_accuracy'], 'g', label='val_accuracy')
plt.ylim([0.1,1])
plt.grid(True)
plt.ylabel('Accuracy')
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.title('Loss')
plt.plot(epochs, history.history['loss'], 'b', label='train_loss')
plt.plot(epochs, history.history['val_loss'], 'g', label='val_loss')
plt.ylim([0,50])
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# > ### Training 이후

# %%
y_out = model.predict(test_data)
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))
Make_Result_Plot("After Training", test_data, test_labels, y_max)
