# %% [markdown]
# # CNN 기반 Classification

# %% [markdown]
# ### [예제 7] Digit Sign-Classifier by CNN: 3 Convolution Layer

# %% [markdown]
# >### Load modules

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import cv2
from sklearn.model_selection import train_test_split

print("NumPy Version :{}".format(np.__version__))
print("TensorFlow Version :{}".format(tf.__version__))
print("Matplotlib Version :{}".format(plt.matplotlib.__version__))
# Out:
# NumPy Version :1.18.5
# TensorFlow Version :2.3.0
# Matplotlib Version :3.2.2

# %% [markdown]
# > ### Load Digit Sign Data

# %%
colab=True
try:
  from google.colab import drive
except:
  colab =False
if colab : 
    drive.mount('/content/drive')
    print('g-drive mounted.')
else : print('local drive.')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# g-drive mounted.

# %%
# file path: 다른 경로에 실습파일을 복사했다면, 아래 경로를 수정하세요

if colab : 
  # !unzip -q -o /content/drive/My\ Drive/files/Sign-Language-Digits-Dataset-master.zip
  files_path = '/content/Sign-Language-Digits-Dataset-master/Dataset/'
else : 
  files_path = 'c:/files/Sign-Language-Digits-Dataset-master/datasets/'

# %%
IMG_SIZE = 64
first = True
for ind in range(0, 10, 1) :
  path = files_path + str(ind) + '/*.*'
  print(path)
  files = glob.glob(path)
  tmpx = np.array([(cv2.resize(cv2.cvtColor(cv2.imread(x, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB), (IMG_SIZE,IMG_SIZE))) for x in files])
  tmpy = np.array([ind] * len(files))
  xtrain, xtest, ytrain, ytest = train_test_split(tmpx, tmpy, test_size=0.2, random_state=123)
  if first == True:
    train_data = xtrain.copy()
    train_labels = ytrain.copy()
    test_data = xtest.copy()
    test_labels = ytest.copy()
    first = False
  else :
    train_data = np.concatenate((train_data, xtrain))
    train_labels = np.concatenate((train_labels, ytrain))
    test_data = np.concatenate((test_data, xtest))
    test_labels = np.concatenate((test_labels, ytest))
# Out:
# /content/Sign-Language-Digits-Dataset-master/Dataset/0/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/1/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/2/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/3/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/4/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/5/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/6/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/7/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/8/*.*
# /content/Sign-Language-Digits-Dataset-master/Dataset/9/*.*

# %%
train_data = train_data.astype(np.double)
train_data = train_data / 255.0

test_data = test_data.astype(np.double)
test_data = test_data / 255.0

print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (1645, 64, 64, 3)
# (1645,)
# (417, 64, 64, 3)
# (417,)

# %% [markdown]
# >### Create Model

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same',activation='sigmoid',input_shape=(IMG_SIZE, IMG_SIZE, 3)))
model.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same',activation='sigmoid'))
# model.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same',activation='sigmoid'))
# model.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 10)                327690
# =================================================================
# Total params: 328,586
# Trainable params: 328,586
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              #loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# >### 결과 출력을 위한 함수

# %%
def Make_Result_Plot(suptitle:str, data:np.ndarray, label:np.ndarray, y_max:np.ndarray):
    fig_result, ax_result = plt.subplots(2,5,figsize=(18, 7))
    fig_result.suptitle(suptitle)
    for idx in range(10):
        ax_result[idx//5][idx%5].imshow(data[idx*40+40].reshape((IMG_SIZE,IMG_SIZE, 3)),cmap="binary")
        ax_result[idx//5][idx%5].set_title("test_data[{}] (label : {} / y : {})".format(idx*40+40, label[idx*40+40], y_max[idx*40+40]))

# %% [markdown]
# > ### 학습 전 상황

# %%
y_out = model.predict(test_data)
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))
Make_Result_Plot("Before Training", test_data, test_labels, y_max)

# %% [markdown]
# > ### 학습 (Training)

# %%
# %%time
history = model.fit(train_data, train_labels, shuffle=True,
                 batch_size=100, epochs=100,
                 validation_data=(test_data, test_labels)
                 )
# Out:
# Epoch 1/100
# 17/17 [==============================] - 0s 22ms/step - loss: 22.9464 - accuracy: 0.0973 - val_loss: 18.3311 - val_accuracy: 0.1007
# Epoch 2/100
# 17/17 [==============================] - 0s 10ms/step - loss: 11.1266 - accuracy: 0.1027 - val_loss: 5.7186 - val_accuracy: 0.1007
# Epoch 3/100
# 17/17 [==============================] - 0s 10ms/step - loss: 4.8585 - accuracy: 0.1040 - val_loss: 2.9754 - val_accuracy: 0.1007
# Epoch 4/100
# 17/17 [==============================] - 0s 9ms/step - loss: 2.8158 - accuracy: 0.1362 - val_loss: 2.6271 - val_accuracy: 0.1007
# Epoch 5/100
# 17/17 [==============================] - 0s 10ms/step - loss: 2.4004 - accuracy: 0.1593 - val_loss: 2.2130 - val_accuracy: 0.2350
# Epoch 6/100
# 17/17 [==============================] - 0s 10ms/step - loss: 2.1771 - accuracy: 0.2614 - val_loss: 2.0805 - val_accuracy: 0.4676
# Epoch 7/100
# 17/17 [==============================] - 0s 9ms/step - loss: 2.0771 - accuracy: 0.2960 - val_loss: 2.0730 - val_accuracy: 0.3333
# Epoch 8/100
# 17/17 [==============================] - 0s 10ms/step - loss: 2.0539 - accuracy: 0.3149 - val_loss: 1.9785 - val_accuracy: 0.3141
# Epoch 9/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.9322 - accuracy: 0.3544 - val_loss: 1.9651 - val_accuracy: 0.2134
# Epoch 10/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.8810 - accuracy: 0.3848 - val_loss: 1.7760 - val_accuracy: 0.4652
# Epoch 11/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.8452 - accuracy: 0.4024 - val_loss: 1.8480 - val_accuracy: 0.3789
# Epoch 12/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.7514 - accuracy: 0.4146 - val_loss: 1.7349 - val_accuracy: 0.4676
# Epoch 13/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.6336 - accuracy: 0.4851 - val_loss: 1.7114 - val_accuracy: 0.3549
# Epoch 14/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.5431 - accuracy: 0.5198 - val_loss: 1.5461 - val_accuracy: 0.4892
# Epoch 15/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.4207 - accuracy: 0.6170 - val_loss: 1.4558 - val_accuracy: 0.5588
# Epoch 16/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.3794 - accuracy: 0.6164 - val_loss: 1.4200 - val_accuracy: 0.5707
# Epoch 17/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.3498 - accuracy: 0.6164 - val_loss: 1.4813 - val_accuracy: 0.5324
# Epoch 18/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.2869 - accuracy: 0.6413 - val_loss: 1.2950 - val_accuracy: 0.6499
# Epoch 19/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.2138 - accuracy: 0.6766 - val_loss: 1.2611 - val_accuracy: 0.6139
# Epoch 20/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.1778 - accuracy: 0.6626 - val_loss: 1.2345 - val_accuracy: 0.6283
# Epoch 21/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.1546 - accuracy: 0.6632 - val_loss: 1.2327 - val_accuracy: 0.6163
# Epoch 22/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.1325 - accuracy: 0.6596 - val_loss: 1.3329 - val_accuracy: 0.5851
# Epoch 23/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.1358 - accuracy: 0.6541 - val_loss: 1.1997 - val_accuracy: 0.6259
# Epoch 24/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.0662 - accuracy: 0.6918 - val_loss: 1.1456 - val_accuracy: 0.6259
# Epoch 25/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.0314 - accuracy: 0.6912 - val_loss: 1.1057 - val_accuracy: 0.6667
# Epoch 26/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.0286 - accuracy: 0.6906 - val_loss: 1.0865 - val_accuracy: 0.6667
# Epoch 27/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.9783 - accuracy: 0.7088 - val_loss: 1.1217 - val_accuracy: 0.6259
# Epoch 28/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.9654 - accuracy: 0.6912 - val_loss: 1.0674 - val_accuracy: 0.6571
# Epoch 29/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.9024 - accuracy: 0.7374 - val_loss: 0.9813 - val_accuracy: 0.7002
# Epoch 30/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.8834 - accuracy: 0.7562 - val_loss: 0.9962 - val_accuracy: 0.7026
# Epoch 31/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.8554 - accuracy: 0.7623 - val_loss: 0.9758 - val_accuracy: 0.7122
# Epoch 32/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.8168 - accuracy: 0.7812 - val_loss: 0.9919 - val_accuracy: 0.6906
# Epoch 33/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.8331 - accuracy: 0.7635 - val_loss: 0.9863 - val_accuracy: 0.6763
# Epoch 34/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.8248 - accuracy: 0.7647 - val_loss: 0.9233 - val_accuracy: 0.7122
# Epoch 35/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7859 - accuracy: 0.7775 - val_loss: 0.9698 - val_accuracy: 0.6811
# Epoch 36/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7929 - accuracy: 0.7678 - val_loss: 0.9234 - val_accuracy: 0.7122
# Epoch 37/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7757 - accuracy: 0.7757 - val_loss: 0.9013 - val_accuracy: 0.7194
# Epoch 38/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.7503 - accuracy: 0.7793 - val_loss: 0.9084 - val_accuracy: 0.7074
# Epoch 39/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7474 - accuracy: 0.7927 - val_loss: 0.8924 - val_accuracy: 0.7266
# Epoch 40/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7574 - accuracy: 0.7696 - val_loss: 0.9423 - val_accuracy: 0.6930
# Epoch 41/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7360 - accuracy: 0.7757 - val_loss: 0.9014 - val_accuracy: 0.7218
# Epoch 42/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6897 - accuracy: 0.8103 - val_loss: 0.8682 - val_accuracy: 0.7458
# Epoch 43/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.6749 - accuracy: 0.8140 - val_loss: 0.8660 - val_accuracy: 0.7266
# Epoch 44/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.6779 - accuracy: 0.8073 - val_loss: 0.8358 - val_accuracy: 0.7506
# Epoch 45/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6876 - accuracy: 0.8036 - val_loss: 0.8849 - val_accuracy: 0.7194
# Epoch 46/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6549 - accuracy: 0.8091 - val_loss: 0.8876 - val_accuracy: 0.7098
# Epoch 47/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.6596 - accuracy: 0.8109 - val_loss: 0.8765 - val_accuracy: 0.7362
# Epoch 48/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6516 - accuracy: 0.8079 - val_loss: 0.8776 - val_accuracy: 0.6978
# Epoch 49/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6323 - accuracy: 0.8134 - val_loss: 0.8482 - val_accuracy: 0.7506
# Epoch 50/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.6247 - accuracy: 0.8274 - val_loss: 0.9106 - val_accuracy: 0.6954
# Epoch 51/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.6257 - accuracy: 0.8170 - val_loss: 0.8524 - val_accuracy: 0.7362
# Epoch 52/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6362 - accuracy: 0.8061 - val_loss: 0.8563 - val_accuracy: 0.7146
# Epoch 53/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.6147 - accuracy: 0.8116 - val_loss: 0.8556 - val_accuracy: 0.7122
# Epoch 54/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5935 - accuracy: 0.8286 - val_loss: 0.8014 - val_accuracy: 0.7482
# Epoch 55/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5837 - accuracy: 0.8316 - val_loss: 0.7988 - val_accuracy: 0.7530
# Epoch 56/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5709 - accuracy: 0.8401 - val_loss: 0.7785 - val_accuracy: 0.7674
# Epoch 57/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5597 - accuracy: 0.8419 - val_loss: 0.8293 - val_accuracy: 0.7242
# Epoch 58/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5873 - accuracy: 0.8310 - val_loss: 0.7964 - val_accuracy: 0.7506
# Epoch 59/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5736 - accuracy: 0.8298 - val_loss: 0.7801 - val_accuracy: 0.7506
# Epoch 60/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5651 - accuracy: 0.8359 - val_loss: 0.8287 - val_accuracy: 0.7410
# Epoch 61/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5409 - accuracy: 0.8474 - val_loss: 0.7709 - val_accuracy: 0.7674
# Epoch 62/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5207 - accuracy: 0.8571 - val_loss: 0.7551 - val_accuracy: 0.7650
# Epoch 63/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5258 - accuracy: 0.8450 - val_loss: 0.7985 - val_accuracy: 0.7434
# Epoch 64/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5398 - accuracy: 0.8541 - val_loss: 0.7936 - val_accuracy: 0.7530
# Epoch 65/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5270 - accuracy: 0.8480 - val_loss: 0.7607 - val_accuracy: 0.7578
# Epoch 66/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5283 - accuracy: 0.8517 - val_loss: 0.7987 - val_accuracy: 0.7530
# Epoch 67/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5299 - accuracy: 0.8480 - val_loss: 0.8129 - val_accuracy: 0.7314
# Epoch 68/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5171 - accuracy: 0.8511 - val_loss: 0.7562 - val_accuracy: 0.7578
# Epoch 69/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4939 - accuracy: 0.8644 - val_loss: 0.7872 - val_accuracy: 0.7578
# Epoch 70/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4837 - accuracy: 0.8675 - val_loss: 0.7520 - val_accuracy: 0.7602
# Epoch 71/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4792 - accuracy: 0.8736 - val_loss: 0.8109 - val_accuracy: 0.7482
# Epoch 72/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5045 - accuracy: 0.8505 - val_loss: 0.7737 - val_accuracy: 0.7602
# Epoch 73/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4770 - accuracy: 0.8657 - val_loss: 0.7587 - val_accuracy: 0.7602
# Epoch 74/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4691 - accuracy: 0.8736 - val_loss: 0.7885 - val_accuracy: 0.7482
# Epoch 75/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4619 - accuracy: 0.8729 - val_loss: 0.7604 - val_accuracy: 0.7554
# Epoch 76/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4637 - accuracy: 0.8723 - val_loss: 0.7529 - val_accuracy: 0.7746
# Epoch 77/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4530 - accuracy: 0.8736 - val_loss: 0.7507 - val_accuracy: 0.7578
# Epoch 78/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4795 - accuracy: 0.8541 - val_loss: 0.7695 - val_accuracy: 0.7458
# Epoch 79/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4646 - accuracy: 0.8608 - val_loss: 0.7554 - val_accuracy: 0.7698
# Epoch 80/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4513 - accuracy: 0.8650 - val_loss: 0.7473 - val_accuracy: 0.7578
# Epoch 81/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4343 - accuracy: 0.8802 - val_loss: 0.7415 - val_accuracy: 0.7578
# Epoch 82/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4376 - accuracy: 0.8736 - val_loss: 0.7418 - val_accuracy: 0.7746
# Epoch 83/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4241 - accuracy: 0.8839 - val_loss: 0.7538 - val_accuracy: 0.7626
# Epoch 84/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4302 - accuracy: 0.8802 - val_loss: 0.7241 - val_accuracy: 0.7626
# Epoch 85/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4218 - accuracy: 0.8802 - val_loss: 0.7378 - val_accuracy: 0.7818
# Epoch 86/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4168 - accuracy: 0.8863 - val_loss: 0.7325 - val_accuracy: 0.7698
# Epoch 87/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4144 - accuracy: 0.8809 - val_loss: 0.7097 - val_accuracy: 0.7818
# Epoch 88/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4059 - accuracy: 0.8827 - val_loss: 0.7245 - val_accuracy: 0.7602
# Epoch 89/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4095 - accuracy: 0.8827 - val_loss: 0.7270 - val_accuracy: 0.7746
# Epoch 90/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4009 - accuracy: 0.8888 - val_loss: 0.7359 - val_accuracy: 0.7578
# Epoch 91/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3882 - accuracy: 0.8900 - val_loss: 0.7417 - val_accuracy: 0.7626
# Epoch 92/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4015 - accuracy: 0.8863 - val_loss: 0.7422 - val_accuracy: 0.7650
# Epoch 93/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3919 - accuracy: 0.8894 - val_loss: 0.7675 - val_accuracy: 0.7578
# Epoch 94/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3967 - accuracy: 0.8845 - val_loss: 0.7701 - val_accuracy: 0.7650
# Epoch 95/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3922 - accuracy: 0.8936 - val_loss: 0.7536 - val_accuracy: 0.7482
# Epoch 96/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3765 - accuracy: 0.9009 - val_loss: 0.7366 - val_accuracy: 0.7578
# Epoch 97/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3810 - accuracy: 0.8839 - val_loss: 0.7846 - val_accuracy: 0.7314
# Epoch 98/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4061 - accuracy: 0.8717 - val_loss: 0.7804 - val_accuracy: 0.7650
# Epoch 99/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4117 - accuracy: 0.8675 - val_loss: 0.8088 - val_accuracy: 0.7410
# Epoch 100/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4117 - accuracy: 0.8754 - val_loss: 0.7441 - val_accuracy: 0.7434
# CPU times: user 16 s, sys: 2.59 s, total: 18.5 s
# Wall time: 18.2 s

# %% [markdown]
# > ### Ploting : Cost/Training Count

# %%
loss = history.history['loss']
epochs = range(1, len(loss)+1)

plt.figure(figsize=(6, 10))
plt.subplot(2, 1, 1)
plt.title('Accuray')
plt.plot(epochs, history.history['accuracy'], 'b', label='train_accuracy')
plt.plot(epochs, history.history['val_accuracy'], 'g', label='val_accuracy')
plt.ylim([0,1])
plt.grid(True)
plt.ylabel('Accuracy')
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.title('Loss')
plt.plot(epochs, history.history['loss'], 'b', label='train_loss')
plt.plot(epochs, history.history['val_loss'], 'g', label='val_loss')
plt.ylim([0,3])
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# > ### Training 이후

# %%
y_out = model.predict(test_data)
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))
Make_Result_Plot("After Training", test_data, test_labels, y_max)
