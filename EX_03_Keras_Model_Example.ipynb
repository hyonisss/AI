# %% [markdown]
# # 모델 구성 훈련 및 평가

# %% [markdown]
# >### Load modules

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

print("TensorFlow Version :{}".format(tf.__version__))
# Out:
# TensorFlow Version :2.3.0

# %% [markdown]
# > ### Load MNIST Data

# %%
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()
train_data, test_data = train_data / 255.0, test_data / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# >### Create Model

# %%
# Sequential Model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.summary()

## Functional Model
# inputs = tf.keras.Input(shape=(28,28))
# x = tf.keras.layers.Flatten()(inputs)
# x = tf.keras.layers.Dense(128, activation='relu')(x)
# predictions = tf.keras.layers.Dense(10, activation='softmax')(x)
# model = tf.keras.Model(inputs=inputs, outputs=predictions)

# model.summary()

# # Subclassing Model by Functional
# class MyModel(tf.keras.Model):
#   def __init__(self):
#     super(MyModel, self).__init__()
#     self.flatten = tf.keras.layers.Flatten(input_shape=(28, 28))
#     self.d1 = tf.keras.layers.Dense(128, activation='relu')
#     self.d2 = tf.keras.layers.Dense(10, activation='softmax')

#   def call(self, x):
#     x = self.flatten(x)
#     x = self.d1(x)
#     return self.d2(x)
# model = MyModel()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# >### Compile Model

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# >### Fit and Evaluate Model

# %%
model.fit(train_data, train_labels, epochs=5)
model.evaluate(test_data, test_labels)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2607 - accuracy: 0.9257
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1142 - accuracy: 0.9665
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0797 - accuracy: 0.9759
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0589 - accuracy: 0.9818
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0461 - accuracy: 0.9858
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0745 - accuracy: 0.9762
# [0.07450668513774872, 0.9761999845504761]
